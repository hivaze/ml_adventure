# %%
import datasets
from datasets import load_dataset
import numpy as np
import nltk
from nltk import tokenize
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/hivaze/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
soda_dataset = load_dataset("allenai/soda")
# Out:
# ...
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset parquet downloaded and prepared to /home/hivaze/.cache/huggingface/datasets/allenai___parquet/allenai--soda-354e990899ae2f4a/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
soda_dataset['train'].features
# Out:
# {'head': Value(dtype='string', id=None),
#  'relation': Value(dtype='string', id=None),
#  'tail': Value(dtype='string', id=None),
#  'literal': Value(dtype='string', id=None),
#  'narrative': Value(dtype='string', id=None),
#  'dialogue': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None),
#  'speakers': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None),
#  'PersonX': Value(dtype='string', id=None),
#  'PersonY': Value(dtype='string', id=None),
#  'PersonZ': Value(dtype='string', id=None),
#  'original_index': Value(dtype='int64', id=None),
#  'split': Value(dtype='string', id=None),
#  'head_answer': Value(dtype='string', id=None),
#  'pmi_head_answer': Value(dtype='string', id=None),
#  'relation_tail_answer': Value(dtype='string', id=None),
#  'pmi_relation_tail_answer': Value(dtype='string', id=None)}

# %%
diag_lengths = [len(diag) for diag in soda_dataset['train']['dialogue']]
np.quantile(diag_lengths, 0.1), np.quantile(diag_lengths, 0.5), np.quantile(diag_lengths, 0.9)
# Out:
# (5.0, 7.0, 11.0)

# %%
soda_dataset['test']['speakers']
# Out:
# [['Malena',
#   'Professor Matthews',
#   'Malena',
#   'Professor Matthews',
#   'Malena',
#   'Professor Matthews',
#   'Malena'],
#  ['Madelynne', 'Friend', 'Madelynne', 'Friend', 'Madelynne', 'Friend'],
#  ['Niyah',
#   'Mother',
#   'Niyah',
#   'Mother',
#   'Niyah',
#   'Mother',
#   'Niyah',
#   'Mother',
#   'Niyah'],
#  ['Ruben', 'Gweneth', 'Ruben', 'Gweneth', 'Ruben', 'Gweneth'],
#  ['Tyrelle', 'Mother', 'Tyrelle', 'Mother', 'Tyrelle', 'Mother'],
#  ['Carlyn', 'Brion', 'Carlyn', 'Brion', 'Carlyn', 'Brion', 'Carlyn', 'Brion'],
#  ['Jozef', 'Toy', 'Jozef', 'Toy', 'Jozef', 'Toy', 'Jozef'],
#  ['Janae', 'Pepper', 'Janae', 'Pepper', 'Janae', 'Pepper', 'Janae', 'Pepper'],
#  ['Ursula', 'Rebeka', 'Ursula', 'Rebeka', 'Ursula', 'Rebeka'],
#  ['Alonso', 'Mother', 'Alonso', 'Mother', 'Alonso', 'Mother'],
#  ['Ferris', 'Anisah', 'Ferris', 'Anisah', 'Ferris', 'Anisah', 'Ferris'],
#  ['Karima', 'Adryan', 'Karima', 'Adryan', 'Adryan', 'Karima'],
#  ['Elisa',
#   'Arthur',
#   'Elisa',
# ...
